# %% [markdown]
# Unsupervised technique that intends to analyze large volumes of text data by clustering the documents into groups. Group the documents into clusters based on similar characteristics.
#
# Non-negative matrix factorization
#     Performs clustering as well as dimensionality reduction.
#     It can be used in combination with TF-IDF scheme to perform topic modeling.

# %%
import os
import pandas as pd
import numpy as np

os.chdir("D:\Choogle\Data\dataset_review")
reviews_datasets = pd.read_csv(r'dataset2_london.csv')
reviews_datasets = reviews_datasets.head(20000)
reviews_datasets.dropna()
# Out:
# Empty DataFrame
# Columns: [crayon_review_id, crayon_user_id, crayon_product_id, domain, url, type, category, date_created, gid, key, g, d, r, product_url, product_name, title, aggregate_rating, value_rating, atmosphere_rating, service_rating, food_rating, service_rating_original, ui_text, text, visited_on, visited_on_month, visited_on_year, via_mobile, review_partnership, reviewed_on, review_year, review_month, review_date, response_given, response_header, response_date, response_text, p_gid, p_url, user_id, user_name, user_location_text, user_city, user_country, user_total_reviews, user_total_reviews_range, user_helpful_reviews, user_helpful_reviews_range, partition_0]
# Index: []
#
# [0 rows x 49 columns]

# %%
#Use TFIDF vectorizer as NMF works with TFIDF. Create a document term matrix with TFIDF.
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(max_df=0.8, min_df=2, stop_words='english')
doc_term_matrix = tfidf_vect.fit_transform(reviews_datasets['text'].values.astype('U'))

# %%
#Create a probability matrix that contains probabilities of all the words in the vocabulary for all the topics. 
#To do so, we use the NMF class from the sklearn.decomposition module.

from sklearn.decomposition import NMF

nmf = NMF(n_components=5, random_state=42)
nmf.fit(doc_term_matrix )
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=5, random_state=42, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
#randomly get 10 words from our vocabulary
import random

for i in range(10):
    random_id = random.randint(0,len(tfidf_vect.get_feature_names()))
    print(tfidf_vect.get_feature_names()[random_id])
# Out:
# parfait
# projector
# chap
# eatery
# deeply
# patrons
# tuscan
# helped
# hour
# days

# %%
#Retrieve the probability vector of words for the first topic and retrieve the indexes of the ten words with the highest probabilities
first_topic = nmf.components_[0]
top_topic_words = first_topic.argsort()[-10:]

# %%
#These indexes can now be passed to the tfidf_vect object to retrieve the actual words
for i in top_topic_words:
    print(tfidf_vect.get_feature_names()[i])
# Out:
# lovely
# night
# excellent
# cocktails
# location
# fantastic
# service
# atmosphere
# food
# great

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 30 words for topic #{i}:')
    print([tfidf_vect.get_feature_names()[i] for i in topic.argsort()[-30:]])
    print('\n')
# Out:
# Top 30 words for topic #0:
# ['especially', 'efficient', 'love', 'time', 'really', 'amazing', 'come', 'fun', 'visited', 'inamo', 'drinks', 'friends', 'highly', 'friendly', 'recommend', 'reasonably', 'value', 'evening', 'priced', 'definitely', 'lovely', 'night', 'excellent', 'cocktails', 'location', 'fantastic', 'service', 'atmosphere', 'food', 'great']
#
#
# Top 30 words for topic #1:
# ['eat', 'took', 'like', 'got', 'asked', 'just', 'tables', 'restaurant', 'waitress', 'wait', 'waiting', 'sushi', 'told', 'arrived', 'didn', 'menu', 'drinks', 'inamo', 'experience', 'came', 'dishes', 'quot', 'minutes', 'interactive', 'did', 'ordered', 'food', 'time', 'order', 'table']
#
#
# Top 30 words for topic #2:
# ['interesting', 'tapas', 'like', 'pork', 'london', 'lunch', 'bread', 'natural', 'extensive', 'octopus', 'nice', 'menu', 'douro', 'dishes', 'bottle', 'charcuterie', 'good', 'terroirs', 'plates', 'selection', 'excellent', 'glass', 'portuguese', 'cheese', 'french', 'wines', 'small', 'list', 'bar', 'wine']
#
#
# Top 30 words for topic #3:
# ['value', 'bit', 'beer', 'different', 'street', 'quick', 'quality', 'excellent', 'meal', 'quite', 'helpful', 'place', 'atmosphere', 'tacos', 'busy', 'fresh', 'price', 'restaurant', 'menu', 'lunch', 'wahaca', 'really', 'friendly', 'service', 'tasty', 'staff', 'nice', 'mexican', 'food', 'good']
#
#
# Top 30 words for topic #4:
# ['thank', 'cake', 'service', 'cheesecake', 'birthday', 'bubbles', 'time', 'special', 'really', 'food', 'experience', 'restaurant', 'super', 'absolutely', 'visit', 'perfect', 'london', 'highly', 'cakes', 'friendly', 'just', 'staff', 'definitely', 'best', 'lovely', 'amp', 'delicious', 'recommend', 'place', 'amazing']

# %%
topic_values = nmf.transform(doc_term_matrix)
reviews_datasets['Topic'] = topic_values.argmax(axis=1)
reviews_datasets.head()
# Out:
#          crayon_review_id          crayon_user_id      crayon_product_id  \
# 0  RR-202001000-552550429  RU-302001000-806642411  R-102001000-202456154
# 1  RR-202001000-550793573  RU-302001000-802600320  R-102001000-202456154
# 2  RR-202001000-533398566  RU-302001000-802928560  R-102001000-200371326
# 3  RR-202001000-556167355  RU-302001000-803691542  R-102001000-200371326
# 4  RR-202001000-545446145  RU-302001000-809584645  R-102001000-200371326
#
#                                            domain  \
# 0  item_1_saturam_restaurant_review_metadata_info
# 1  item_1_saturam_restaurant_review_metadata_info
# 2  item_1_saturam_restaurant_review_metadata_info
# 3  item_1_saturam_restaurant_review_metadata_info
# 4  item_1_saturam_restaurant_review_metadata_info
#
#                                                  url     type     category  \
# 0  https://item_1_saturam_restaurant_review_metad...  Reviews  Restaurants
# 1  https://item_1_saturam_restaurant_review_metad...  Reviews  Restaurants
# 2  https://item_1_saturam_restaurant_review_metad...  Reviews  Restaurants
# 3  https://item_1_saturam_restaurant_review_metad...  Reviews  Restaurants
# 4  https://item_1_saturam_restaurant_review_metad...  Reviews  Restaurants
#
#   date_created                                                gid  \
# 0   2019-04-11  item_1_saturam_restaurant_review_metadata_info...
# 1   2019-04-11  item_1_saturam_restaurant_review_metadata_info...
# 2   2019-04-12  item_1_saturam_restaurant_review_metadata_info...
# 3   2019-04-12  item_1_saturam_restaurant_review_metadata_info...
# 4   2019-04-12  item_1_saturam_restaurant_review_metadata_info...
#
#                                                  key  ...       user_name  \
# 0  ef65c514583b9254dbd8f794c516aaca21c864076d59e3...  ...   Stevetarn2014
# 1  e766851ea18b154b154e419691d4ee7eeb4db9d80333f4...  ...  T35BZcristinag
# 2  982dced88fd267e522b3591a402d2a3f5d3cb8bc783bdd...  ...         Q1487BW
# 3  ffdeac1f47ee1b9e21e3bf54869d87e1b9ab7b9a55d02f...  ...           Ian M
# 4  cf0e41f130196d008f51f301712f0f48e572472e4532a1...  ...         gillank
#
#         user_location_text  user_city     user_country user_total_reviews  \
# 0   London, United Kingdom     London   United Kingdom                423
# 1                      NaN        NaN              NaN                141
# 2  Bristol, United Kingdom    Bristol   United Kingdom                  8
# 3                      NaN        NaN              NaN                  6
# 4           Hanoi, Vietnam      Hanoi          Vietnam                140
#
#   user_total_reviews_range  user_helpful_reviews  user_helpful_reviews_range  \
# 0               101 to 500                  1030                1001 to 5000
# 1               101 to 500                     9                    1 to 100
# 2                 1 to 100                     2                    1 to 100
# 3                 1 to 100                     1                    1 to 100
# 4               101 to 500                    41                    1 to 100
#
#                                          partition_0  Topic
# 0  item_1_restaurant_review_20190609_v10_stage4_c...      3
# 1  item_1_restaurant_review_20190609_v10_stage4_c...      0
# 2  item_1_restaurant_review_20190609_v10_stage4_c...      0
# 3  item_1_restaurant_review_20190609_v10_stage4_c...      3
# 4  item_1_restaurant_review_20190609_v10_stage4_c...      3
#
# [5 rows x 50 columns]
